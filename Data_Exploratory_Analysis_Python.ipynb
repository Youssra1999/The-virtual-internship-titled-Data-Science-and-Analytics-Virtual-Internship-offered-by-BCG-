# %%
# Import necessary libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Shows plots in jupyter notebook
# %matplotlib inline

# Set plot style
sns.set(color_codes=True)

# Load data from your Google Drive (assuming you've uploaded the CSV files there)
client_df = pd.read_csv("/content/drive/MyDrive/client_data.csv")
price_df = pd.read_csv("/content/drive/MyDrive/price_data.csv")

# %%
client_df.head(3)
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# 0      2015-11-01   2015-06-23               0.00  ...        t       0.0
# 1      2009-08-21   2015-08-31             189.95  ...        f       0.0
# 2      2010-04-16   2015-04-17              47.96  ...        f       0.0
#
#    margin_gross_pow_ele  margin_net_pow_ele  nb_prod_act  net_margin  \
# ...

# %%
# Display the first few rows of the data
print(client_df.head())
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  d29c2c54acc38ff3c0614d0a653813dd                           MISSING
# 2  764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua
# 3  bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema
# 4  149d57cf92fc41cf94415803a877cb4b                           MISSING
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1      4660             0                0  2009-08-21  2016-08-30
# 2       544             0                0  2010-04-16  2016-04-16
# 3      1584             0                0  2010-03-30  2016-03-30
# 4      4425             0              526  2010-01-13  2016-03-07
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  has_gas  imp_cons  \
# ...

# %%
# Get an overview of the data's columns and data types
print(client_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14606 entries, 0 to 14605
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              14606 non-null  object
#  1   channel_sales                   14606 non-null  object
#  2   cons_12m                        14606 non-null  int64
#  3   cons_gas_12m                    14606 non-null  int64
#  4   cons_last_month                 14606 non-null  int64
#  5   date_activ                      14606 non-null  object
#  6   date_end                        14606 non-null  object
#  7   date_modif_prod                 14606 non-null  object
#  8   date_renewal                    14606 non-null  object
#  9   forecast_cons_12m               14606 non-null  float64
#  10  forecast_cons_year              14606 non-null  int64
#  11  forecast_discount_energy        14606 non-null  float64
# ...

# %%
# Check for missing values
print(client_df.isnull().sum())
# Out:
# id                                0
# channel_sales                     0
# cons_12m                          0
# cons_gas_12m                      0
# cons_last_month                   0
# date_activ                        0
# date_end                          0
# date_modif_prod                   0
# date_renewal                      0
# forecast_cons_12m                 0
# forecast_cons_year                0
# forecast_discount_energy          0
# forecast_meter_rent_12m           0
# forecast_price_energy_off_peak    0
# forecast_price_energy_peak        0
# forecast_price_pow_off_peak       0
# has_gas                           0
# imp_cons                          0
# margin_gross_pow_ele              0
# margin_net_pow_ele                0
# nb_prod_act                       0
# net_margin                        0
# num_years_antig                   0
# origin_up                         0
# pow_max                           0
# churn                             0
# ...

# %%
client_df.describe()
# Out:
#            cons_12m  cons_gas_12m  cons_last_month  forecast_cons_12m  \
# count  1.460600e+04  1.460600e+04     14606.000000       14606.000000
# mean   1.592203e+05  2.809238e+04     16090.269752        1868.614880
# std    5.734653e+05  1.629731e+05     64364.196422        2387.571531
# min    0.000000e+00  0.000000e+00         0.000000           0.000000
# 25%    5.674750e+03  0.000000e+00         0.000000         494.995000
# 50%    1.411550e+04  0.000000e+00       792.500000        1112.875000
# 75%    4.076375e+04  0.000000e+00      3383.000000        2401.790000
# max    6.207104e+06  4.154590e+06    771203.000000       82902.830000
#
#        forecast_cons_year  forecast_discount_energy  forecast_meter_rent_12m  \
# count        14606.000000              14606.000000             14606.000000
# mean          1399.762906                  0.966726                63.086871
# std           3247.786255                  5.108289                66.165783
# ...

# %%
def plot_stacked_bars(dataframe, title_, size_=(18, 10), rot_=0, legend_="upper right"):
    """
    Plot stacked bars with annotations
    """
    ax = dataframe.plot(
        kind="bar",
        stacked=True,
        figsize=size_,
        rot=rot_,
        title=title_
    )

    # Annotate bars
    annotate_stacked_bars(ax, textsize=14)
    # Rename legend
    plt.legend(["Retention", "Churn"], loc=legend_)
    # Labels
    plt.ylabel("Company base (%)")
    plt.show()

def annotate_stacked_bars(ax, pad=0.99, colour="white", textsize=13):
    """
    Add value annotations to the bars
    """

    # Iterate over the plotted rectanges/bars
    for p in ax.patches:

        # Calculate annotation
        value = str(round(p.get_height(),1))
        # If value is 0 do not annotate
        if value == '0.0':
            continue
        ax.annotate(
            value,
            ((p.get_x()+ p.get_width()/2)*pad-0.05, (p.get_y()+p.get_height()/2)*pad),
            color=colour,
            size=textsize
        )

def plot_distribution(dataframe, column, ax, bins_=50):
    """
    Plot variable distirbution in a stacked histogram of churned or retained company
    """
    # Create a temporal dataframe with the data to be plot
    temp = pd.DataFrame({"Retention": dataframe[dataframe["churn"]==0][column],
    "Churn":dataframe[dataframe["churn"]==1][column]})
    # Plot the histogram
    temp[["Retention","Churn"]].plot(kind='hist', bins=bins_, ax=ax, stacked=True)
    # X-axis label
    ax.set_xlabel(column)
    # Change the x-axis to plain style
    ax.ticklabel_format(style='plain', axis='x')

# %%
churn = client_df[['id', 'churn']]
churn.columns = ['Companies', 'churn']
churn_total = churn.groupby(churn['churn']).count()
churn_percentage = churn_total / churn_total.sum() * 100
plot_stacked_bars(churn_percentage.transpose(), "Churning status", (5, 5), legend_="lower right")

# %%
consumption = client_df[['id', 'cons_12m', 'cons_gas_12m', 'cons_last_month', 'imp_cons', 'has_gas', 'churn']]

fig, axs = plt.subplots(nrows=1, figsize=(18, 5))

plot_distribution(consumption, 'cons_12m', axs)

# %%
categorical_columns = [ 'channel_sales', 'origin_up', 'has_gas']

# Create subplots for the distribution of categorical columns by churn
plt.figure(figsize=(12, 8))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(2, 2, i)
    sns.countplot(x=column, hue='churn', data=client_df)
    plt.title(f'Distribution of {column} by Churn')
    plt.xticks(rotation=45)

plt.tight_layout()

# %%
# Calculate churn rate within each category
category_churn_rate = client_df.groupby('channel_sales')['churn'].mean().sort_values(ascending=False)

# Print the categories with their corresponding churn rates
print(category_churn_rate)
# Out:
# channel_sales
# foosdfpfkusacimwkcsosbicdxkicaua    0.121410
# usilxuppasemubllopkaafesmlibmsdf    0.100364
# ewpakwlliwisiwduibdlfmalxowmwpci    0.083987
# MISSING                             0.075973
# lmkebamcaaclubfxadlmueccxoimlema    0.055887
# epumfxlbckeskwekxbiuasklxalciiuu    0.000000
# fixdbufsefwooaasfcxdxadsiekoceaa    0.000000
# sddiedcslfslkckwlfkdpoeeailfpeds    0.000000
# Name: churn, dtype: float64

# %%
# Calculate churn rate within each category
category_churn_rate = client_df.groupby('origin_up')['churn'].mean().sort_values(ascending=False)

# Print the categories with their corresponding churn rates
print(category_churn_rate)
# Out:
# origin_up
# lxidpiddsbxsbosboudacockeimpuepw    0.125828
# ldkssxwpmemidmecebumciepifcamkci    0.083863
# MISSING                             0.062500
# kamkkxfxxuwbdslkwifmmcsiusiuosws    0.060084
# ewxeelcelemmiwuafmddpobolfuxioce    0.000000
# usapbepcfoloekilkwsdiboslwaxobdp    0.000000
# Name: churn, dtype: float64

# %%
# Calculate churn rate within each category
category_churn_rate = client_df.groupby('has_gas')['churn'].mean().sort_values(ascending=False)

# Print the categories with their corresponding churn rates
print(category_churn_rate)
# Out:
# has_gas
# f    0.100544
# t    0.081856
# Name: churn, dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=category_churn_rate.index, y=category_churn_rate.values)
plt.xticks(rotation=45)
plt.xlabel('Gas consumption')
plt.ylabel('Churn Rate')
plt.title('Churn Rate by Activity Category')
plt.tight_layout()
plt.show()

# %%
numeric_columns = ['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m', 'forecast_cons_year',
                   'forecast_discount_energy', 'forecast_meter_rent_12m', 'forecast_price_energy_off_peak',
                   'forecast_price_energy_peak', 'forecast_price_pow_off_peak', 'imp_cons', 'margin_gross_pow_ele',
                   'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig', 'pow_max']

# Create subplots for numeric columns' distribution by churn
plt.figure(figsize=(18, 15))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(6, 3, i)
    sns.boxplot(x='churn', y=column, data=client_df)
    plt.title(f'{column} Distribution by Churn')

plt.tight_layout()
plt.show()

# Calculate correlation between numeric columns
numeric_corr = client_df[numeric_columns].corr()
sns.heatmap(numeric_corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# Create histograms for numeric columns
numeric_columns = ['cons_12m', 'cons_gas_12m', 'cons_last_month', 'forecast_cons_12m', 'forecast_cons_year',
                   'forecast_discount_energy', 'forecast_meter_rent_12m', 'imp_cons', 'margin_gross_pow_ele',
                   'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig', 'pow_max']
plt.figure(figsize=(12, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(4, 4, i)
    sns.histplot(data=client_df, x=column, kde=True)
    plt.title(f'Distribution of {column}')

plt.tight_layout()
plt.show()

# %%
# Calculate churn rate
churn_rate = client_df['churn'].mean()
print(f"Churn Rate: {churn_rate:.2%}")
# Out:
# Churn Rate: 9.72%

# %%
import matplotlib.pyplot as plt

# Create a histogram for the distribution of cons_12m
plt.figure(figsize=(10, 6))
plt.hist(client_df['cons_12m'], bins=20, edgecolor='black')
plt.xlabel('Electricity Consumption (cons_12m)')
plt.ylabel('Frequency')
plt.title('Distribution of Electricity Consumption')
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a histogram for the distribution of cons_12m
plt.figure(figsize=(10, 6))
plt.hist(client_df['cons_last_month'], bins=20, edgecolor='black')
plt.xlabel('Electricity Consumption (cons_12m)')
plt.ylabel('Frequency')
plt.title('Distribution of Electricity Consumption')
plt.show()

# %%
channel_counts = client_df['channel_sales'].value_counts()
print(channel_counts)
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    6754
# MISSING                             3725
# lmkebamcaaclubfxadlmueccxoimlema    1843
# usilxuppasemubllopkaafesmlibmsdf    1375
# ewpakwlliwisiwduibdlfmalxowmwpci     893
# sddiedcslfslkckwlfkdpoeeailfpeds      11
# epumfxlbckeskwekxbiuasklxalciiuu       3
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: channel_sales, dtype: int64

# %%
origin_counts = client_df['origin_up'].value_counts()
print(origin_counts)
# Out:
# lxidpiddsbxsbosboudacockeimpuepw    7097
# kamkkxfxxuwbdslkwifmmcsiusiuosws    4294
# ldkssxwpmemidmecebumciepifcamkci    3148
# MISSING                               64
# usapbepcfoloekilkwsdiboslwaxobdp       2
# ewxeelcelemmiwuafmddpobolfuxioce       1
# Name: origin_up, dtype: int64

# %%
churn_by_channel = client_df.groupby('channel_sales')['churn'].mean()
churn_by_origin = client_df.groupby('origin_up')['churn'].mean()

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.barplot(x=churn_by_channel.index, y=churn_by_channel.values)
plt.title('Churn Rate by Channel Sales')

plt.subplot(1, 2, 2)
sns.barplot(x=churn_by_origin.index, y=churn_by_origin.values)
plt.title('Churn Rate by Origin Up')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
sns.boxplot(x='churn', y='cons_12m', data=client_df)
plt.title('Churn vs. Electricity Consumption')

plt.subplot(1, 3, 2)
sns.boxplot(x='churn', y='imp_cons', data=client_df)
plt.title('Churn vs. Current Paid Consumption')

plt.subplot(1, 3, 3)
sns.boxplot(x='churn', y='num_years_antig', data=client_df)
plt.title('Churn vs. Antiquity (Years)')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create a new column to categorize antiquity ranges
bins = [0, 2, 5, 10, 20, float('inf')]
labels = ['<2', '2-5', '5-10', '10-20', '20+']
client_df['antiquity_range'] = pd.cut(client_df['num_years_antig'], bins=bins, labels=labels)

# Calculate churn rate for each antiquity range
churn_by_antiquity = client_df.groupby('antiquity_range')['churn'].mean()

# Create a bar plot to visualize churn rate by antiquity range
plt.figure(figsize=(10, 6))
sns.barplot(x=churn_by_antiquity.index, y=churn_by_antiquity.values)
plt.xlabel('Antiquity Range (Years)')
plt.ylabel('Churn Rate')
plt.title('Churn Rate by Antiquity Range')
plt.show()

# %%
price_df.head(3)
# Out:
#                                  id  price_date  price_off_peak_var  \
# 0  038af19179925da21a25619c5a24b745  2015-01-01            0.151367
# 1  038af19179925da21a25619c5a24b745  2015-02-01            0.151367
# 2  038af19179925da21a25619c5a24b745  2015-03-01            0.151367
#
#    price_peak_var  price_mid_peak_var  price_off_peak_fix  price_peak_fix  \
# 0             0.0                 0.0           44.266931             0.0
# 1             0.0                 0.0           44.266931             0.0
# 2             0.0                 0.0           44.266931             0.0
#
#    price_mid_peak_fix
# 0                 0.0
# 1                 0.0
# 2                 0.0

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193002 entries, 0 to 193001
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  193002 non-null  object
#  1   price_date          193002 non-null  object
#  2   price_off_peak_var  193002 non-null  float64
#  3   price_peak_var      193002 non-null  float64
#  4   price_mid_peak_var  193002 non-null  float64
#  5   price_off_peak_fix  193002 non-null  float64
#  6   price_peak_fix      193002 non-null  float64
#  7   price_mid_peak_fix  193002 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.8+ MB

# %%
price_df.describe()
# Out:
#        price_off_peak_var  price_peak_var  price_mid_peak_var  \
# count       193002.000000   193002.000000       193002.000000
# mean             0.141027        0.054630            0.030496
# std              0.025032        0.049924            0.036298
# min              0.000000        0.000000            0.000000
# 25%              0.125976        0.000000            0.000000
# 50%              0.146033        0.085483            0.000000
# 75%              0.151635        0.101673            0.072558
# max              0.280700        0.229788            0.114102
#
#        price_off_peak_fix  price_peak_fix  price_mid_peak_fix
# count       193002.000000   193002.000000       193002.000000
# mean            43.334477       10.622875            6.409984
# std              5.410297       12.841895            7.773592
# min              0.000000        0.000000            0.000000
# 25%             40.728885        0.000000            0.000000
# ...

# %%
import pandas as pd

# Assuming client_data and price_data are loaded into DataFrames

# Merge the datasets based on the 'id' column
merged_data = client_df.merge(price_df, on='id', how='inner')

# Explore the merged dataset
print(merged_data.head())
# Out:
#                                  id                     channel_sales  \
# 0  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 1  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 2  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 3  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
# 4  24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua
#
#    cons_12m  cons_gas_12m  cons_last_month  date_activ    date_end  \
# 0         0         54946                0  2013-06-15  2016-06-15
# 1         0         54946                0  2013-06-15  2016-06-15
# 2         0         54946                0  2013-06-15  2016-06-15
# 3         0         54946                0  2013-06-15  2016-06-15
# 4         0         54946                0  2013-06-15  2016-06-15
#
#   date_modif_prod date_renewal  forecast_cons_12m  ...  pow_max  churn  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_off_peak_var', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_peak_var', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_mid_peak_var', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_off_peak_fix', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_peak_fix', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explore price variations by churn status
plt.figure(figsize=(10, 6))

# Price of energy for the 1st period (off peak)
sns.boxplot(x='churn', y='price_mid_peak_fix', data=merged_data)
plt.xlabel('Churn')
plt.ylabel('Price of Energy (Off Peak)')
plt.title('Price Variation vs. Churn')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create scatter plot for 'price_off_peak_fix'
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price_mid_peak_var', y='churn', data=merged_data, hue='churn')
plt.xlabel('Price of Energy (Off Peak)')
plt.ylabel('Churn')
plt.title('Scatter Plot: Price of Energy (Off Peak) vs. Churn')
plt.legend(title='Churn', loc='upper right', labels=['Non-Churned', 'Churned'])
plt.show()

# %%
# Convert date columns to datetime
client_df['date_activ'] = pd.to_datetime(client_df['date_activ'])
# ... similar conversions for other date columns ...

# Set date columns as index
client_df.set_index('date_activ', inplace=True)
# ... set other date columns as index ...

# Plot time series of energy prices (off peak and peak)
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
client_df['forecast_price_energy_off_peak'].plot(label='Energy Price (Off Peak)')
plt.xlabel('Date')
plt.ylabel('Energy Price')
plt.title('Time Series Analysis: Energy Price (Off Peak)')
plt.legend()

plt.subplot(2, 1, 2)
client_df['forecast_price_energy_peak'].plot(label='Energy Price (Peak)')
plt.xlabel('Date')
plt.ylabel('Energy Price')
plt.title('Time Series Analysis: Energy Price (Peak)')
plt.legend()

plt.tight_layout()
plt.show()

# Plot time series of churn rates
plt.figure(figsize=(10, 6))
client_df['churn'].plot(label='Churn Rate', color='red')
plt.xlabel('Date')
plt.ylabel('Churn Rate')
plt.title('Time Series Analysis: Churn Rates')
plt.legend()
plt.show()
